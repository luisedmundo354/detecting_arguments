# %% [markdown]
# # IAA Results
#
# This notebook validates the repaired overlap set, computes the existing span and sentence baselines, and adds both direct-edge agreement and implicit intermediate-conclusion insertion agreement for edit-distance and semantic pair matching.

# %%
from pathlib import Path
import sys


def find_repo_root(start: Path) -> Path:
    for candidate in [start] + list(start.parents):
        if (candidate / "annotations").is_dir() and (candidate / "iaa_scores").is_dir():
            return candidate
    raise RuntimeError(f"Could not find repo root starting from {start}")


repo_root = find_repo_root(Path.cwd().resolve())
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

input_dir = repo_root / "annotations" / "final_annotations_iaa_set"
cache_dir = repo_root / "iaa_scores" / "cache"
input_dir
# Out:
# PosixPath('/home/lbrenap/Documents/projects/detecting_arguments/annotations/final_annotations_iaa_set')

# %%
from iaa_scores.annotation_graphs import validate_repaired_iaa_exports


validate_repaired_iaa_exports(input_dir)
print(f"Validated repaired IAA exports in {input_dir}")
print(f"Cache directory: {cache_dir}")
# Out:
# Validated repaired IAA exports in /home/lbrenap/Documents/projects/detecting_arguments/annotations/final_annotations_iaa_set
# Cache directory: /home/lbrenap/Documents/projects/detecting_arguments/iaa_scores/cache

# %%
from iaa_scores.alpha import compute_alpha_u_overall, compute_alpha_u_per_doc
from iaa_scores.agreement_summaries import summarize_explicit_spans_from_pair_cache
from iaa_scores.corpus import build_corpus
from iaa_scores.edge_agreement import evaluate_edge_agreement_from_pair_cache
from iaa_scores.f1_scores import compute_f1_from_pair_cache
from iaa_scores.implicit_insertion_agreement import evaluate_implicit_insertion_agreement_from_pair_cache
from iaa_scores.models import AlphaMode
from iaa_scores.pair_cache import build_or_load_pair_cache, pair_cache_path
from iaa_scores.pipeline import evaluate_corpus
from iaa_scores.semantic_cache import (
    build_or_load_semantic_embedding_cache,
    semantic_cache_paths,
)
from iaa_scores.sentence_corpus import build_sentence_corpus


edit_metric = "yujianbo"
edit_min_sim = 0.1

semantic_model = "embed-v4.0"
semantic_input_type = "classification"
semantic_output_dimension = 512
semantic_min_sim = 0.0

overwrite_edit_pairs = False
overwrite_semantic_embeddings = False
overwrite_semantic_pairs = False

sample_context_limit = 5

# %%
corpus = build_corpus(input_dir, min_annotators=2)
print(f"Found {len(corpus.files)} files; included {len(corpus.doc_spans)} documents")
print("Categories:", corpus.categories)

per_doc_alpha_u = {
    ref_id: compute_alpha_u_per_doc(
        corpus.doc_offsets[ref_id],
        corpus.categories,
        continuum_len=corpus.doc_lengths.get(ref_id),
        include_background=True,
    )
    for ref_id in sorted(corpus.doc_offsets)
}

overall_alpha_u = compute_alpha_u_overall(
    corpus.doc_offsets,
    corpus.categories,
    include_background=True,
    doc_lengths=corpus.doc_lengths,
)

print("Per-document span alpha_u by category:")
for ref_id in sorted(per_doc_alpha_u):
    annotators = len(corpus.doc_spans.get(ref_id, {}))
    print(f"\n-- ref_id: {ref_id} (annotators: {annotators}) --")
    for cat in corpus.categories:
        print(f"  {cat}: {per_doc_alpha_u[ref_id].get(cat)}")

print("\nOverall span alpha_u by category:")
for cat in corpus.categories:
    print(f"  {cat}: {overall_alpha_u.get(cat)}")
# Out:
# Found 20 files; included 10 documents
# Categories: ['Analysis', 'Background Facts', 'Conclusion', 'Procedural History', 'Rule']
# Per-document span alpha_u by category:
#
# -- ref_id: 4 (annotators: 2) --
#   Analysis: 0.5037963454127594
#   Background Facts: 0.9989852189593874
#   Conclusion: 1.0
#   Procedural History: -0.010531914893616934
#   Rule: 0.6841713123325418
#
# -- ref_id: 5 (annotators: 2) --
#   Analysis: 0.6167070001572549
#   Background Facts: 0.6749841145713855
#   Conclusion: 1.0
#   Procedural History: -0.05287123106686176
#   Rule: 0.5711367034791868
#
# -- ref_id: 6 (annotators: 2) --
#   Analysis: 0.17282843731593722
#   Background Facts: 0.972803590793567
#   Conclusion: 1.0
#   Procedural History: 0.667112925241009
#   Rule: 0.4496890659346584
#
# -- ref_id: 7 (annotators: 2) --
#   Analysis: 0.6615328958404703
#   Background Facts: 0.4907807592107821
#   Conclusion: 1.0
#   Procedural History: 0.21959484244080307
#   Rule: 0.9122341302397033
#
# ...

# %%
edit_pair_cache = build_or_load_pair_cache(
    repo_root=repo_root,
    input_dir=input_dir,
    backend="edit",
    overwrite=overwrite_edit_pairs,
    metric=edit_metric,
    min_sim=edit_min_sim,
)
edit_pair_cache_path = pair_cache_path(
    repo_root=repo_root,
    input_dir=input_dir,
    backend="edit",
    metric=edit_metric,
    min_sim=edit_min_sim,
    semantic_cache=None,
)
print(f"Edit pair cache: {edit_pair_cache_path}")

explicit_span_summary = summarize_explicit_spans_from_pair_cache(edit_pair_cache)
print("Explicit spans per label in the 10-case IAA set (by annotator):")
print(explicit_span_summary["overall_by_annotator"])
print("Explicit spans per label in the 10-case IAA set (combined):")
print(explicit_span_summary["overall_combined"])

per_doc_span_f1, span_pair_counts, overall_span_f1 = compute_f1_from_pair_cache(
    edit_pair_cache,
    corpus.categories,
)
print("Per-document span F1 by category (edit-distance pairs):")
for ref_id in sorted(per_doc_span_f1):
    annotators = len(corpus.doc_spans.get(ref_id, {}))
    print(f"\n-- ref_id: {ref_id} (annotators: {annotators}) --")
    for cat in corpus.categories:
        print(f"  {cat}: {per_doc_span_f1[ref_id].get(cat)}")

print("\nOverall span F1 by category (edit-distance pairs):")
for cat in corpus.categories:
    print(f"  {cat}: {overall_span_f1.get(cat)}")
# Out:
# Edit pair cache: /home/lbrenap/Documents/projects/detecting_arguments/iaa_scores/cache/pairs/final_annotations_iaa_set__pairs__edit_yujianbo__min0p1__label_restricted.json
# Explicit spans per label in the 10-case IAA set (by annotator):
# {'gdeyesu@umaryland.edu': {'Analysis': 44, 'Background Facts': 13, 'Conclusion': 10, 'Procedural History': 14, 'Rule': 36}, 'zaidal-huneidi@umaryland.edu': {'Analysis': 80, 'Background Facts': 12, 'Conclusion': 10, 'Procedural History': 14, 'Rule': 52}}
# Explicit spans per label in the 10-case IAA set (combined):
# {'Analysis': 124, 'Background Facts': 25, 'Conclusion': 20, 'Procedural History': 28, 'Rule': 88}
# Per-document span F1 by category (edit-distance pairs):
#
# -- ref_id: 4 (annotators: 2) --
#   Analysis: 0.14298645843177238
#   Background Facts: 0.525328330206379
#   Conclusion: 1.0
#   Procedural History: 0.0
#   Rule: 0.491186856883474
#
# -- ref_id: 5 (annotators: 2) --
#   Analysis: 0.6482355277885301
# ...

# %%
edit_edge_scores = evaluate_edge_agreement_from_pair_cache(input_dir, edit_pair_cache)
print("Per-document direct-edge agreement (edit-distance pairs):")
for ref_id in sorted(edit_edge_scores.per_doc):
    doc_result = edit_edge_scores.per_doc[ref_id]
    print(f"\n-- ref_id: {ref_id} --")
    print("  files:", ", ".join(path.name for path in doc_result.files))
    print("  annotators:", ", ".join(doc_result.annotators))
    print("  context_count:", doc_result.context_count)
    print("  agreement_count:", doc_result.agreement_count)
    print("  observed_agreement:", doc_result.observed_agreement)
    print("  expected_agreement:", doc_result.expected_agreement)
    print("  kappa:", doc_result.kappa)
    print("  positive_rate_by_annotator:", doc_result.positive_rate_by_annotator)

print("\nOverall direct-edge agreement (edit-distance pairs):")
print("  overall_context_count:", edit_edge_scores.overall_context_count)
print("  overall_agreement_count:", edit_edge_scores.overall_agreement_count)
print("  overall_observed_agreement:", edit_edge_scores.overall_observed_agreement)
print("  overall_expected_agreement:", edit_edge_scores.overall_expected_agreement)
print("  overall_kappa:", edit_edge_scores.overall_kappa)
print("  overall_positive_rate_by_annotator:", edit_edge_scores.overall_positive_rate_by_annotator)
# Out:
# Per-document direct-edge agreement (edit-distance pairs):
#
# -- ref_id: 4 --
#   files: 35_gdeyesu.json, 85_zaidal-huneidi.json
#   annotators: gdeyesu@umaryland.edu, zaidal-huneidi@umaryland.edu
#   context_count: 10
#   agreement_count: 0
#   observed_agreement: 0.0
#   expected_agreement: 0.32
#   kappa: -0.4705882352941177
#   positive_rate_by_annotator: {'gdeyesu@umaryland.edu': 0.8, 'zaidal-huneidi@umaryland.edu': 0.2}
#
# -- ref_id: 5 --
#   files: 64_gdeyesu.json, 63_zaidal-huneidi.json
#   annotators: gdeyesu@umaryland.edu, zaidal-huneidi@umaryland.edu
#   context_count: 11
#   agreement_count: 0
#   observed_agreement: 0.0
#   expected_agreement: 0.4628099173553719
#   kappa: -0.8615384615384616
#   positive_rate_by_annotator: {'gdeyesu@umaryland.edu': 0.6363636363636364, 'zaidal-huneidi@umaryland.edu': 0.36363636363636365}
#
# -- ref_id: 6 --
#   files: 57_gdeyesu.json, 90_zaidal-huneidi.json
#   annotators: gdeyesu@umaryland.edu, zaidal-huneidi@umaryland.edu
# ...

# %%
edit_insertion_scores = evaluate_implicit_insertion_agreement_from_pair_cache(
    input_dir,
    edit_pair_cache,
    sample_context_limit=sample_context_limit,
)
print("Per-document implicit insertion agreement (edit-distance pairs):")
for ref_id in sorted(edit_insertion_scores.per_doc):
    doc_result = edit_insertion_scores.per_doc[ref_id]
    print(f"\n-- ref_id: {ref_id} --")
    print("  files:", ", ".join(path.name for path in doc_result.files))
    print("  annotators:", ", ".join(doc_result.annotators))
    print("  context_count:", doc_result.context_count)
    print("  agreement_count:", doc_result.agreement_count)
    print("  yes_yes_count:", doc_result.yes_yes_count)
    print("  yes_no_count:", doc_result.yes_no_count)
    print("  no_yes_count:", doc_result.no_yes_count)
    print("  no_no_count:", doc_result.no_no_count)
    print("  observed_agreement:", doc_result.observed_agreement)
    print("  expected_agreement:", doc_result.expected_agreement)
    print("  kappa:", doc_result.kappa)
    print("  positive_agreement:", doc_result.positive_agreement)
    print("  negative_agreement:", doc_result.negative_agreement)
    print("  insertion_rate_by_annotator:", doc_result.insertion_rate_by_annotator)
    print("  usable_implicit_nodes_by_annotator:", doc_result.usable_implicit_nodes_by_annotator)
    print("  excluded_implicit_nodes_by_annotator:", doc_result.excluded_implicit_nodes_by_annotator)
    print("  context_source_counts:", doc_result.context_source_counts)
    print("  sample_contexts:", doc_result.sample_contexts)

print("\nOverall implicit insertion agreement (edit-distance pairs):")
print("  overall_context_count:", edit_insertion_scores.overall_context_count)
print("  overall_agreement_count:", edit_insertion_scores.overall_agreement_count)
print("  overall_yes_yes_count:", edit_insertion_scores.overall_yes_yes_count)
print("  overall_yes_no_count:", edit_insertion_scores.overall_yes_no_count)
print("  overall_no_yes_count:", edit_insertion_scores.overall_no_yes_count)
print("  overall_no_no_count:", edit_insertion_scores.overall_no_no_count)
print("  overall_observed_agreement:", edit_insertion_scores.overall_observed_agreement)
print("  overall_expected_agreement:", edit_insertion_scores.overall_expected_agreement)
print("  overall_kappa:", edit_insertion_scores.overall_kappa)
print("  overall_positive_agreement:", edit_insertion_scores.overall_positive_agreement)
print("  overall_negative_agreement:", edit_insertion_scores.overall_negative_agreement)
print("  overall_insertion_rate_by_annotator:", edit_insertion_scores.overall_insertion_rate_by_annotator)
print("  overall_usable_implicit_nodes_by_annotator:", edit_insertion_scores.overall_usable_implicit_nodes_by_annotator)
print("  overall_excluded_implicit_nodes_by_annotator:", edit_insertion_scores.overall_excluded_implicit_nodes_by_annotator)
# Out:
# Per-document implicit insertion agreement (edit-distance pairs):
#
# -- ref_id: 4 --
#   files: 35_gdeyesu.json, 85_zaidal-huneidi.json
#   annotators: gdeyesu@umaryland.edu, zaidal-huneidi@umaryland.edu
#   context_count: 6
#   agreement_count: 4
#   yes_yes_count: 0
#   yes_no_count: 0
#   no_yes_count: 2
#   no_no_count: 4
#   observed_agreement: 0.6666666666666666
#   expected_agreement: 0.6666666666666667
#   kappa: -3.3306690738754706e-16
#   positive_agreement: 0.0
#   negative_agreement: 0.8
#   insertion_rate_by_annotator: {'gdeyesu@umaryland.edu': 0.0, 'zaidal-huneidi@umaryland.edu': 0.3333333333333333}
#   usable_implicit_nodes_by_annotator: {'gdeyesu@umaryland.edu': 0, 'zaidal-huneidi@umaryland.edu': 3}
#   excluded_implicit_nodes_by_annotator: {'gdeyesu@umaryland.edu': {}, 'zaidal-huneidi@umaryland.edu': {'no_parent': 1, 'unmatched_explicit_parent': 3}}
# ...

# %%
sentence_corpus = build_sentence_corpus(input_dir, min_annotators=2)
print(f"Sentence-view documents: {len(sentence_corpus.doc_spans)}")
print("Sentence categories:", sentence_corpus.categories)

sentence_scores = evaluate_corpus(
    sentence_corpus,
    alpha_mode=AlphaMode.UNITIZING,
    include_background=True,
    metric=edit_metric,
    min_sim=edit_min_sim,
)

print("Per-document sentence F1 by category:")
for ref_id in sorted(sentence_scores.per_doc_f1):
    annotators = len(sentence_corpus.doc_spans.get(ref_id, {}))
    print(f"\n-- ref_id: {ref_id} (annotators: {annotators}) --")
    for cat in sentence_corpus.categories:
        print(f"  {cat}: {sentence_scores.per_doc_f1[ref_id].get(cat)}")

print("\nOverall sentence F1 by category:")
for cat in sentence_corpus.categories:
    print(f"  {cat}: {sentence_scores.overall_f1.get(cat)}")

print("\nPer-document sentence alpha_u by category:")
for ref_id in sorted(sentence_scores.per_doc_alpha):
    annotators = len(sentence_corpus.doc_spans.get(ref_id, {}))
    print(f"\n-- ref_id: {ref_id} (annotators: {annotators}) --")
    for cat in sentence_corpus.categories:
        print(f"  {cat}: {sentence_scores.per_doc_alpha[ref_id].get(cat)}")

print("\nOverall sentence alpha_u by category:")
for cat in sentence_corpus.categories:
    print(f"  {cat}: {sentence_scores.overall_alpha.get(cat)}")
# Out:
# Sentence-view documents: 10
# Sentence categories: ['Analysis', 'Background Facts', 'Conclusion', 'Procedural History', 'Rule']
# ...
# Scoring documents: 100%|██████████| 10/10 [06:02<00:00, 36.21s/it]
# Per-document sentence F1 by category:
#
# -- ref_id: 4 (annotators: 2) --
#   Analysis: 0.7487733424977826
#   Background Facts: 1.0
#   Conclusion: 1.0
#   Procedural History: 0.0
#   Rule: 0.8097315729173538
#
# -- ref_id: 5 (annotators: 2) --
#   Analysis: 0.591030303030303
#   Background Facts: 0.7547169811320755
#   Conclusion: 1.0
#   Procedural History: 0.18317841732501386
#   Rule: 0.7325107337453551
#
# -- ref_id: 6 (annotators: 2) --
#   Analysis: 0.4393944768849446
#   Background Facts: 0.975609756097561
#   Conclusion: 1.0
#   Procedural History: 0.7272727272727273
#   Rule: 0.5776888065252733
#
# -- ref_id: 7 (annotators: 2) --
#   Analysis: 0.7321490769766631
#   Background Facts: 0.6956521739130436
#   Conclusion: 1.0
#   Procedural History: 0.3271274961597542
# ...

# %%
semantic_cache = build_or_load_semantic_embedding_cache(
    repo_root=repo_root,
    input_dir=input_dir,
    overwrite=overwrite_semantic_embeddings,
    model=semantic_model,
    input_type=semantic_input_type,
    output_dimension=semantic_output_dimension,
)
semantic_npz_path, semantic_manifest_path = semantic_cache_paths(
    repo_root=repo_root,
    input_dir=input_dir,
    model=semantic_model,
    input_type=semantic_input_type,
    output_dimension=semantic_output_dimension,
)
print(f"Semantic embedding matrix: {semantic_npz_path}")
print(f"Semantic embedding manifest: {semantic_manifest_path}")

semantic_pair_cache = build_or_load_pair_cache(
    repo_root=repo_root,
    input_dir=input_dir,
    backend="semantic",
    overwrite=overwrite_semantic_pairs,
    min_sim=semantic_min_sim,
    semantic_cache=semantic_cache,
)
semantic_pair_cache_path = pair_cache_path(
    repo_root=repo_root,
    input_dir=input_dir,
    backend="semantic",
    metric=None,
    min_sim=semantic_min_sim,
    semantic_cache=semantic_cache,
)
print(f"Semantic pair cache: {semantic_pair_cache_path}")
# Out:
# Semantic embedding matrix: /home/lbrenap/Documents/projects/detecting_arguments/iaa_scores/cache/embeddings/final_annotations_iaa_set__cohere_embed-v4.0__classification__dim512__float.npz
# Semantic embedding manifest: /home/lbrenap/Documents/projects/detecting_arguments/iaa_scores/cache/embeddings/final_annotations_iaa_set__cohere_embed-v4.0__classification__dim512__float.manifest.json
# Semantic pair cache: /home/lbrenap/Documents/projects/detecting_arguments/iaa_scores/cache/pairs/final_annotations_iaa_set__pairs__semantic_cohere_embed-v4.0__classification__dim512__cosine__min0__label_restricted.json

# %%
semantic_per_doc_f1, semantic_pair_counts, semantic_overall_f1 = compute_f1_from_pair_cache(
    semantic_pair_cache,
    corpus.categories,
)
print("Per-document span F1 by category (semantic pairs):")
for ref_id in sorted(semantic_per_doc_f1):
    annotators = len(corpus.doc_spans.get(ref_id, {}))
    print(f"\n-- ref_id: {ref_id} (annotators: {annotators}) --")
    for cat in corpus.categories:
        print(f"  {cat}: {semantic_per_doc_f1[ref_id].get(cat)}")

print("\nOverall span F1 by category (semantic pairs):")
for cat in corpus.categories:
    print(f"  {cat}: {semantic_overall_f1.get(cat)}")
# Out:
# Per-document span F1 by category (semantic pairs):
#
# -- ref_id: 4 (annotators: 2) --
#   Analysis: 0.26434908835030063
#   Background Facts: 0.642957653870413
#   Conclusion: 1.0
#   Procedural History: 0.0
#   Rule: 0.6577201512550028
#
# -- ref_id: 5 (annotators: 2) --
#   Analysis: 0.8063973245622136
#   Background Facts: 0.9047354863214105
#   Conclusion: 1.0
#   Procedural History: 0.6834829496781997
#   Rule: 0.5009751413841164
#
# -- ref_id: 6 (annotators: 2) --
#   Analysis: 0.33779616782433697
#   Background Facts: 0.9860235742813769
#   Conclusion: 0.9999999999999998
#   Procedural History: 0.8526127712185938
#   Rule: 0.5087402222225215
#
# -- ref_id: 7 (annotators: 2) --
#   Analysis: 0.5691754957770666
#   Background Facts: 0.6190692082700356
#   Conclusion: 1.0000000000000002
#   Procedural History: 0.41757059682076403
#   Rule: 0.8
#
# -- ref_id: 8 (annotators: 2) --
#   Analysis: 0.47766116044840823
#   Background Facts: 0.620771987516551
# ...

# %%
semantic_edge_scores = evaluate_edge_agreement_from_pair_cache(input_dir, semantic_pair_cache)
print("Per-document direct-edge agreement (semantic pairs):")
for ref_id in sorted(semantic_edge_scores.per_doc):
    doc_result = semantic_edge_scores.per_doc[ref_id]
    print(f"\n-- ref_id: {ref_id} --")
    print("  files:", ", ".join(path.name for path in doc_result.files))
    print("  annotators:", ", ".join(doc_result.annotators))
    print("  context_count:", doc_result.context_count)
    print("  agreement_count:", doc_result.agreement_count)
    print("  observed_agreement:", doc_result.observed_agreement)
    print("  expected_agreement:", doc_result.expected_agreement)
    print("  kappa:", doc_result.kappa)
    print("  positive_rate_by_annotator:", doc_result.positive_rate_by_annotator)

print("\nOverall direct-edge agreement (semantic pairs):")
print("  overall_context_count:", semantic_edge_scores.overall_context_count)
print("  overall_agreement_count:", semantic_edge_scores.overall_agreement_count)
print("  overall_observed_agreement:", semantic_edge_scores.overall_observed_agreement)
print("  overall_expected_agreement:", semantic_edge_scores.overall_expected_agreement)
print("  overall_kappa:", semantic_edge_scores.overall_kappa)
print("  overall_positive_rate_by_annotator:", semantic_edge_scores.overall_positive_rate_by_annotator)
# Out:
# Per-document direct-edge agreement (semantic pairs):
#
# -- ref_id: 4 --
#   files: 35_gdeyesu.json, 85_zaidal-huneidi.json
#   annotators: gdeyesu@umaryland.edu, zaidal-huneidi@umaryland.edu
#   context_count: 9
#   agreement_count: 0
#   observed_agreement: 0.0
#   expected_agreement: 0.1975308641975309
#   kappa: -0.2461538461538462
#   positive_rate_by_annotator: {'gdeyesu@umaryland.edu': 0.8888888888888888, 'zaidal-huneidi@umaryland.edu': 0.1111111111111111}
#
# -- ref_id: 5 --
#   files: 64_gdeyesu.json, 63_zaidal-huneidi.json
#   annotators: gdeyesu@umaryland.edu, zaidal-huneidi@umaryland.edu
#   context_count: 12
#   agreement_count: 0
#   observed_agreement: 0.0
#   expected_agreement: 0.48611111111111105
#   kappa: -0.9459459459459457
#   positive_rate_by_annotator: {'gdeyesu@umaryland.edu': 0.5833333333333334, 'zaidal-huneidi@umaryland.edu': 0.4166666666666667}
#
# -- ref_id: 6 --
#   files: 57_gdeyesu.json, 90_zaidal-huneidi.json
# ...

# %%
semantic_insertion_scores = evaluate_implicit_insertion_agreement_from_pair_cache(
    input_dir,
    semantic_pair_cache,
    sample_context_limit=sample_context_limit,
)
print("Per-document implicit insertion agreement (semantic pairs):")
for ref_id in sorted(semantic_insertion_scores.per_doc):
    doc_result = semantic_insertion_scores.per_doc[ref_id]
    print(f"\n-- ref_id: {ref_id} --")
    print("  files:", ", ".join(path.name for path in doc_result.files))
    print("  annotators:", ", ".join(doc_result.annotators))
    print("  context_count:", doc_result.context_count)
    print("  agreement_count:", doc_result.agreement_count)
    print("  yes_yes_count:", doc_result.yes_yes_count)
    print("  yes_no_count:", doc_result.yes_no_count)
    print("  no_yes_count:", doc_result.no_yes_count)
    print("  no_no_count:", doc_result.no_no_count)
    print("  observed_agreement:", doc_result.observed_agreement)
    print("  expected_agreement:", doc_result.expected_agreement)
    print("  kappa:", doc_result.kappa)
    print("  positive_agreement:", doc_result.positive_agreement)
    print("  negative_agreement:", doc_result.negative_agreement)
    print("  insertion_rate_by_annotator:", doc_result.insertion_rate_by_annotator)
    print("  usable_implicit_nodes_by_annotator:", doc_result.usable_implicit_nodes_by_annotator)
    print("  excluded_implicit_nodes_by_annotator:", doc_result.excluded_implicit_nodes_by_annotator)
    print("  context_source_counts:", doc_result.context_source_counts)
    print("  sample_contexts:", doc_result.sample_contexts)

print("\nOverall implicit insertion agreement (semantic pairs):")
print("  overall_context_count:", semantic_insertion_scores.overall_context_count)
print("  overall_agreement_count:", semantic_insertion_scores.overall_agreement_count)
print("  overall_yes_yes_count:", semantic_insertion_scores.overall_yes_yes_count)
print("  overall_yes_no_count:", semantic_insertion_scores.overall_yes_no_count)
print("  overall_no_yes_count:", semantic_insertion_scores.overall_no_yes_count)
print("  overall_no_no_count:", semantic_insertion_scores.overall_no_no_count)
print("  overall_observed_agreement:", semantic_insertion_scores.overall_observed_agreement)
print("  overall_expected_agreement:", semantic_insertion_scores.overall_expected_agreement)
print("  overall_kappa:", semantic_insertion_scores.overall_kappa)
print("  overall_positive_agreement:", semantic_insertion_scores.overall_positive_agreement)
print("  overall_negative_agreement:", semantic_insertion_scores.overall_negative_agreement)
print("  overall_insertion_rate_by_annotator:", semantic_insertion_scores.overall_insertion_rate_by_annotator)
print("  overall_usable_implicit_nodes_by_annotator:", semantic_insertion_scores.overall_usable_implicit_nodes_by_annotator)
print("  overall_excluded_implicit_nodes_by_annotator:", semantic_insertion_scores.overall_excluded_implicit_nodes_by_annotator)
# Out:
# Per-document implicit insertion agreement (semantic pairs):
#
# -- ref_id: 4 --
#   files: 35_gdeyesu.json, 85_zaidal-huneidi.json
#   annotators: gdeyesu@umaryland.edu, zaidal-huneidi@umaryland.edu
#   context_count: 6
#   agreement_count: 3
#   yes_yes_count: 0
#   yes_no_count: 0
#   no_yes_count: 3
#   no_no_count: 3
#   observed_agreement: 0.5
#   expected_agreement: 0.5
#   kappa: 0.0
#   positive_agreement: 0.0
#   negative_agreement: 0.6666666666666666
#   insertion_rate_by_annotator: {'gdeyesu@umaryland.edu': 0.0, 'zaidal-huneidi@umaryland.edu': 0.5}
#   usable_implicit_nodes_by_annotator: {'gdeyesu@umaryland.edu': 0, 'zaidal-huneidi@umaryland.edu': 5}
#   excluded_implicit_nodes_by_annotator: {'gdeyesu@umaryland.edu': {}, 'zaidal-huneidi@umaryland.edu': {'no_parent': 1, 'unmatched_explicit_parent': 1}}
# ...
