# %%
import pandas as pd
import argumentmining
import numpy as np

# read data
df_sentences = pd.read_pickle("df_sentences.pkl")
df_annotations = pd.read_pickle("df_annotations.pkl")

# %%
df_sentences.head(20)
# Out:
#                                              Document  Split  Name  \
# 0   A2008_Commission of the European Communities v...      1  prem
# 1   A2008_Commission of the European Communities v...      1  prem
# 2   A2008_Commission of the European Communities v...      1  prem
# 3   A2008_Commission of the European Communities v...      1  prem
# 4   A2008_Commission of the European Communities v...      1  prem
# 5   A2008_Commission of the European Communities v...      1  prem
# 6   A2008_Commission of the European Communities v...      1  prem
# 7   A2008_Commission of the European Communities v...      1  prem
# 8   A2008_Commission of the European Communities v...      1  prem
# 9   A2008_Commission of the European Communities v...      1  prem
# 10  A2008_Commission of the European Communities v...      1  prem
# 11  A2008_Commission of the European Communities v...      1  prem
# 12  A2008_Commission of the European Communities v...      1  prem
# ...

# %%
df_annotations.head()['Text'].loc[0]
# Out:
# 'e could rely authorisation even implicit aid covered contested decision based provision nn– Findings Courtnn31 must held first Article 4c CS prohibits granting State aid steel coal undertakings without drawing distinction individual aid aid disbursed State aid scheme Article 67 CS refers expressly State aid respect protective measures Commission may authorise pursuant first indent'

# %%
df_annotations.head(30)
# Out:
#                                              Document  Split  Name   Id  \
# 0   A2008_Commission of the European Communities v...      1  prem   A1
# 1   A2008_Commission of the European Communities v...      1  prem   A2
# 2   A2008_Commission of the European Communities v...      1  prem   A3
# 3   A2008_Commission of the European Communities v...      1  prem   A4
# 4   A2008_Commission of the European Communities v...      1  prem   A5
# 5   A2008_Commission of the European Communities v...      1  prem   A6
# 6   A2008_Commission of the European Communities v...      1  prem   A7
# 7   A2008_Commission of the European Communities v...      1  prem   A8
# 8   A2008_Commission of the European Communities v...      1  prem   A9
# 9   A2008_Commission of the European Communities v...      1  prem  A10
# 10  A2008_Commission of the European Communities v...      1  prem  A11
# 11  A2008_Commission of the European Communities v...      1  prem  A12
# ...

# %%
df_annotations.columns
# Out:
# Index(['Document', 'Split', 'Name', 'Id', 'Text', 'Type', 'Scheme'], dtype='object')

# %%
df_sentences.columns
# Out:
# Index(['Document', 'Split', 'Name', 'Text'], dtype='object')

# %%
np.array(df_sentences.loc[0])
# Out:
# array(['A2008_Commission of the European Communities v Salzgitter AG', 1,
#        'prem',
#        'e could rely authorisation even implicit aid covered contested decision based provision nn– Findings Courtnn31 must held first Article 4c CS prohibits granting State aid steel coal undertakings without drawing distinction individual aid aid disbursed State aid scheme Article 67 CS refers expressly State aid respect protective measures Commission may authorise pursuant first indent'],
#       dtype=object)

# %%
np.array(df_annotations.loc[0])
# Out:
# array(['A2008_Commission of the European Communities v Salzgitter AG', 1,
#        'prem', 'A1',
#        'e could rely authorisation even implicit aid covered contested decision based provision nn– Findings Courtnn31 must held first Article 4c CS prohibits granting State aid steel coal undertakings without drawing distinction individual aid aid disbursed State aid scheme Article 67 CS refers expressly State aid respect protective measures Commission may authorise pursuant first indent',
#        'L', 'Rule'], dtype=object)
